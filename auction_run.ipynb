# %%
import numpy as np

class Auction:
    '''Class to represent an online second-price ad auction'''
    
    def __init__(self, users, bidders):
        '''Initializing users (list), bidders (list), and dictionary to store balances for each bidder in the auction'''
        self.users = users
        self.bidders = bidders
        
        # balances for each bidder in the auction
        self.balances = {bidder:0 for bidder in self.bidders}
        print(f'bidder balance dict = {self.balances}')

    def __repr__(self):
        '''Return auction object with users and qualified bidders'''
        return f'Auction with users={self.users} and self.bidders={[bidder for bidder, balance in self.balances.items() if balance > -1000]}'

    def __str__(self):
        '''Return auction object with users and qualified bidders'''
        return self.__repr__()

    def execute_round(self):
        '''Executes a single round of an auction, completing the following steps:
            - random user selection
            - bids from every qualified bidder in the auction
            - selection of winning bidder based on maximum bid
            - selection of actual price (second-highest bid)
            - showing ad to user and finding out whether or not they click
            - notifying winning bidder of price and user outcome and updating balance
            - notifying losing bidders of price'''
        
        # choose a user at random
        user_id = np.random.randint(0, len(self.users))
        user_prob = self.users[user_id]
        print(f'Chosen user is {user_id} with probability {user_prob}')

        # collect bids from every qualified bidder in the auction
        bids = {}
        for bidder in self.balances:
            if self.balances[bidder] > -1000:
                bids[bidder] = bidder.bid(user_id)
        print(f'{bids=}')

        # select winning bidder    
        winning_bid = max(bids.values())
        print(f'{winning_bid=}')
        
        # determine which bidder(s) are associated with max bid
        winning_bidders = [bidder for bidder, bid in bids.items() if bid == winning_bid]
        print(f'{winning_bidders=}')
        
        # break a tie
        if len(winning_bidders) == 1:
            winner = winning_bidders[0]
            print(f'{winner=}')
            bids.pop(winner)
            print(f'bids sans winner = {bids}')
        else:
            winners_index = np.random.randint(0, len(winning_bidders))
            winner = winning_bidders[winners_index]
            print(f'{winner=}')
            bids.pop(winner)
            print(f'bids sans winner = {bids}')

        # selection of actual price
        if len(bids) == 0:
            price = winning_bid
        else:
            price = max(bids.values())

        # show ad to user and find out whether or not they click
        did_user_click = user_prob.show_ad()
        
        # update Auction balances
        self.balances[winner] -= price
        if did_user_click == True:
            self.balances[winner] += 1

        # notify winner of its new balance
        winner.balance = self.balances[winner]

        # notify bidders of price
        for bidder in self.bidders:
            if bidder != winner:
                auction_winner = False
                did_user_click = None
            elif bidder == winner:
                auction_winner = True
            print(f'{auction_winner=}')
            bidder.notify(auction_winner, price, did_user_click)

# %%
class User:
    '''Class to represent a user with a secret probability of clicking an ad.'''

    def __init__(self):
        self.__probability = np.random.uniform()

    def __repr__(self):
        return str(self.__probability)
    
    def __str__(self):
        '''User object with a secret likelihood of clicking on an ad'''
        return self.__repr__()

    def show_ad(self):
        '''Returns True to represent the user clicking on an ad or False otherwise'''
        result = np.random.choice([True, False], p=[self.__probability, 1 - self.__probability])
        return result

# %%
class Bidder:
    '''Class to represent a bidder in an online second-price ad auction'''
    
    def __init__(self, num_users, num_rounds):
        '''Setting number of users (int), number of rounds (int), and round counter'''

        # number of users in Auction
        self.__num_users = num_users
        # total number of rounds to be played in Auction
        self.__num_rounds = num_rounds
        # each Bidder begins with a balance of 0 dollars
        self.__balance = 0.0

    def __repr__(self):
       '''Return Bidder object'''
       return f'Random Bidder with balance = {self.__balance}'

    def __str__(self):
        '''Return Bidder object'''
        return self.__repr__()

    def bid(self, user_id):
        '''Returns a non-negative bid amount'''
        # a bid is any non-negative amount of money in dollars rounded to 3 decimal places
        self.__user = user_id
        return round(np.random.uniform(0,1), 3)
            

    def notify(self, auction_winner, price, clicked):
        '''Updates bidder attributes based on results from an auction round'''
        self.__auction_winner = auction_winner
        self.__price = price
        self.__clicked = clicked

# %%
num_rounds = 100
num_users = 1
num_bidders = 1

bidders = [Bidder(num_users, num_rounds) for i in range(num_bidders)]
users = [User() for i in range(num_users)]
auction = Auction(users, bidders)

for round_number in range(num_rounds):
    print('-'*50)
    print(f'{round_number = }')
    auction.execute_round()
# Out:
# bidder balance dict = {Random Bidder with balance = 0.0: 0}
# --------------------------------------------------
# round_number = 0
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.09}
# winning_bid=0.09
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 1
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.646}
# winning_bid=0.646
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 2
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.532}
# winning_bid=0.532
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 3
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.348}
# winning_bid=0.348
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 4
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.064}
# winning_bid=0.064
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 5
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.474}
# winning_bid=0.474
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 6
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.639}
# winning_bid=0.639
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 7
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.278}
# winning_bid=0.278
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 8
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.335}
# winning_bid=0.335
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 9
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.836}
# winning_bid=0.836
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 10
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.497}
# winning_bid=0.497
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 11
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.186}
# winning_bid=0.186
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 12
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.8}
# winning_bid=0.8
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 13
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.508}
# winning_bid=0.508
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 14
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.466}
# winning_bid=0.466
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 15
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.11}
# winning_bid=0.11
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 16
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.836}
# winning_bid=0.836
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 17
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.432}
# winning_bid=0.432
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 18
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.207}
# winning_bid=0.207
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 19
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.966}
# winning_bid=0.966
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 20
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.163}
# winning_bid=0.163
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 21
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.817}
# winning_bid=0.817
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 22
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.046}
# winning_bid=0.046
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 23
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.284}
# winning_bid=0.284
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 24
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.912}
# winning_bid=0.912
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 25
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.653}
# winning_bid=0.653
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 26
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.467}
# winning_bid=0.467
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 27
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.424}
# winning_bid=0.424
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 28
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.202}
# winning_bid=0.202
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 29
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.841}
# winning_bid=0.841
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 30
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.73}
# winning_bid=0.73
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 31
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.863}
# winning_bid=0.863
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 32
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.666}
# winning_bid=0.666
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 33
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.631}
# winning_bid=0.631
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 34
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.452}
# winning_bid=0.452
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 35
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.986}
# winning_bid=0.986
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 36
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.323}
# winning_bid=0.323
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 37
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.975}
# winning_bid=0.975
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 38
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.412}
# winning_bid=0.412
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 39
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.44}
# winning_bid=0.44
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 40
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.989}
# winning_bid=0.989
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 41
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.413}
# winning_bid=0.413
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 42
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.344}
# winning_bid=0.344
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 43
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.349}
# winning_bid=0.349
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 44
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.211}
# winning_bid=0.211
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 45
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.816}
# winning_bid=0.816
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 46
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.223}
# winning_bid=0.223
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 47
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.494}
# winning_bid=0.494
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 48
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.216}
# winning_bid=0.216
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 49
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.403}
# winning_bid=0.403
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 50
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.291}
# winning_bid=0.291
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 51
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.842}
# winning_bid=0.842
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 52
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.112}
# winning_bid=0.112
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 53
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.188}
# winning_bid=0.188
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 54
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.43}
# winning_bid=0.43
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 55
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.836}
# winning_bid=0.836
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 56
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.464}
# winning_bid=0.464
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 57
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.85}
# winning_bid=0.85
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 58
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.179}
# winning_bid=0.179
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 59
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.43}
# winning_bid=0.43
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 60
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.777}
# winning_bid=0.777
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 61
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.226}
# winning_bid=0.226
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 62
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.992}
# winning_bid=0.992
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 63
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.773}
# winning_bid=0.773
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 64
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.431}
# winning_bid=0.431
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 65
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.065}
# winning_bid=0.065
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 66
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.404}
# winning_bid=0.404
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 67
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.379}
# winning_bid=0.379
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 68
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.892}
# winning_bid=0.892
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 69
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.156}
# winning_bid=0.156
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 70
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.448}
# winning_bid=0.448
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 71
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.956}
# winning_bid=0.956
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 72
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.764}
# winning_bid=0.764
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 73
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.978}
# winning_bid=0.978
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 74
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.657}
# winning_bid=0.657
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 75
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.97}
# winning_bid=0.97
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 76
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.748}
# winning_bid=0.748
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 77
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.253}
# winning_bid=0.253
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 78
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.618}
# winning_bid=0.618
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 79
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.731}
# winning_bid=0.731
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 80
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.935}
# winning_bid=0.935
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 81
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.387}
# winning_bid=0.387
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 82
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.126}
# winning_bid=0.126
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 83
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.985}
# winning_bid=0.985
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 84
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.988}
# winning_bid=0.988
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 85
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.255}
# winning_bid=0.255
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 86
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.693}
# winning_bid=0.693
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 87
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.657}
# winning_bid=0.657
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 88
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.557}
# winning_bid=0.557
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 89
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.792}
# winning_bid=0.792
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 90
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.604}
# winning_bid=0.604
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 91
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.269}
# winning_bid=0.269
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 92
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.224}
# winning_bid=0.224
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 93
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.542}
# winning_bid=0.542
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 94
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.247}
# winning_bid=0.247
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 95
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.311}
# winning_bid=0.311
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 96
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.673}
# winning_bid=0.673
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 97
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.66}
# winning_bid=0.66
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 98
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.298}
# winning_bid=0.298
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
# --------------------------------------------------
# round_number = 99
# Chosen user is 0 with probability 0.46605700697977837
# bids={Random Bidder with balance = 0.0: 0.169}
# winning_bid=0.169
# winning_bidders=[Random Bidder with balance = 0.0]
# winner=Random Bidder with balance = 0.0
# bids sans winner = {}
# auction_winner=True
